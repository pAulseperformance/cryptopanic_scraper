# %%
# df['Currencies'].apply(', '.join)

# %%
#  Now that the data is cleaned and we have a backup of our df let's explore
from bokeh.plotting import figure, output_notebook, show
output_notebook()
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral5, Spectral3, inferno, viridis, Category20
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eaa22502-2ee8-4116-b1ce-02e804e16a5a">Loading BokehJS ...</span>
#     </div>

# %%
source = ColumnDataSource(df)
types = df['Currencies'].unique().tolist()
color_map = factor_cmap(field_name='Currencies', palette=viridis(18), factors=types)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19d756d1f50c> in <module>()
# ----> 1 source = ColumnDataSource(df)
#       2 types = df['Currencies'].unique().tolist()
#       3 color_map = factor_cmap(field_name='Currencies', palette=viridis(18), factors=types)
#
# NameError: name 'df' is not defined

# %%
p = figure(x_axis_type='datetime')

p.circle(x='Date', y='positive', source=source, size=10, color=color_map)

# p.title.text = 'Pokemon Attack vs Speed'
# p.xaxis.axis_label = 'Attacking Stats'
# p.yaxis.axis_label = 'Speed Stats'

hover = HoverTool()
hover.tooltips=[
    ('Positive', '@positive'),
    ('Negative', '@negative'),
    ('Important', '@{important}'),
    ('Title', '@Title'),
]

p.add_tools(hover)

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-46ae5460b647> in <module>()
#       1 p = figure(x_axis_type='datetime')
#       2
# ----> 3 p.circle(x='Date', y='positive', source=source, size=10, color=color_map)
#       4
#       5 # p.title.text = 'Pokemon Attack vs Speed'
#
# NameError: name 'source' is not defined

# %%
attribs = df.groupby('Currencies')['positive'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c109df33eff6> in <module>()
# ----> 1 attribs = df.groupby('Currencies')['positive'].mean()
#
# NameError: name 'df' is not defined

# %%
df = pd.concat([df.drop(['Currencies'], axis=1), df['Currencies'].apply(pd.Series)], axis=1).fillna(0)
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-feee7c479492> in <module>()
# ----> 1 df = pd.concat([df.drop(['Currencies'], axis=1), df['Currencies'].apply(pd.Series)], axis=1).fillna(0)
#       2 df.describe()
#
# NameError: name 'pd' is not defined
